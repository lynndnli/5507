# %% [markdown]
# # 1. Word Frequency

# %%
import re
import gensim
import jieba
import pandas as pd
import warnings
import csv

# ignore DeprecationWarnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# read in CSV file containing text data
df = pd.read_csv('/Users/Lynn/Downloads/red/merged.csv', encoding="utf-8-sig")

def sent_to_words_lower(sentences):
    for sent in sentences:
        sent = sent.lower()
        sent = re.sub(r'http\S+|https\S+', '', sent)  # remove http and https
        sent = re.sub('<[^>]+>', '', sent)  # remove HTML tags
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub('[^\w\s]', ' ', sent)  # remove punctuations
        sent = re.sub('@\w+', '', sent)
        yield sent

# apply sent_to_words_lower function to 'note_desc' column and convert resulting generator to list
note_desc_lower = list(sent_to_words_lower(df['note_desc'].astype(str).values.tolist()))

# define function to tokenize Chinese text using jieba and remove stopwords
def tokenize(text):
    # load user-defined dictionary for jieba
    jieba.load_userdict("dict.txt")
    
    # define function to check if character is Chinese
    def is_chinese(uchar):
        if uchar >= '\u4e00' and uchar <= '\u9fa5':
            return True
        else:
            return False
    
    # define function to tokenize text using jieba and remove stopwords
    def seg_depart(sentence):
        sentence_depart = jieba.cut(sentence.strip())
        outstr = ''
        for word in sentence_depart:
            # check if word is Chinese and not a stopword
            if is_chinese(word) and len(word.strip()) > 0:
                outstr += word
                outstr += " "
        return outstr
    
    # apply seg_depart function to each document in text and split resulting string into list of words
    tokenized = [seg_depart(doc).split(' ')[:-1] for doc in text]
    
    return tokenized

# apply tokenize function to note_desc_lower list to tokenize and remove stopwords
note_desc_tokenized = tokenize(note_desc_lower)

# define function to generate bigrams and trigrams from tokenized text data
def generate_ngrams(texts):
    # generate bigrams and trigrams
    bigram = gensim.models.Phrases(texts, min_count=10, threshold=10)
    trigram = gensim.models.Phrases(bigram[texts], min_count=10, threshold=10)
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    trigram_mod = gensim.models.phrases.Phraser(trigram)

    # apply bigram and trigram models to each document in text and return resulting list of tokenized documents
    ngram_tokenized = [trigram_mod[bigram_mod[doc]] for doc in texts]

    return ngram_tokenized

# apply generate_ngrams function to note_desc_tokenized list to generate bigrams and trigrams
note_desc_ngram = generate_ngrams(note_desc_tokenized)

# create dictionary of term frequencies
term_freq = {}
for doc in note_desc_ngram:
    for term in doc:
        if term in term_freq:
            term_freq[term] += 1
        else:
            term_freq[term] = 1

# sort dictionary by frequency and write to CSV file
sorted_term_freq = sorted(term_freq.items(), key=lambda x: x[1], reverse=True)
print(sorted_term_freq)
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /var/folders/g3/whtrsvys0vg0n49n23hq5v180000gp/T/jieba.cache
# Loading model cost 0.621 seconds.
# Prefix dict has been built successfully.
开麦', 73), ('计划_话题', 73), ('马超', 73), ('战绩', 72), ('再', 72), ('一般', 72), ('一点', 72), ('举报', 71), ('应该', 71), ('之前', 71), ('对抗_路', 71), ('虽然', 70), ('单排', 69), ('一样', 69), ('玩游戏', 69), ('只', 68), ('发现', 68), ('是不是', 68), ('以后', 68), ('当时', 68), ('蔡文姬', 68), ('太', 67), ('位', 67), ('大招', 67), ('女性', 67), ('不过', 66), ('这些', 66), ('话题_游戏_分享', 65), ('出来', 65), ('以为', 65), ('偷笑', 65), ('等', 65), ('王者_创作者_成长_计划', 65), ('真', 64), ('不想', 64), ('后来', 64), ('挺', 64), ('娱乐', 64), ('希望', 64), ('星', 64), ('选择', 64), ('推荐', 64), ('看看', 63), ('中单', 63), ('拉', 63), ('比', 63), ('阵容', 63), ('们', 62), ('抢', 62), ('巅峰', 62), ('别', 62), ('有人', 62), ('那么', 61), ('哭_惹', 60), ('歧视', 60), ('主页', 60), ('选', 60), ('一个_人', 59), ('对象', 59), ('人家', 59), ('开', 58), ('巅峰_赛', 58), ('生气', 58), ('叫', 58), ('骂人', 58), ('更', 58), ('局', 58), ('送', 58), ('为了', 58), ('赛季', 58), ('下', 57), ('经济', 57), ('快乐', 57), ('起来', 57), ('一次', 57), ('打完', 57), ('为', 57), ('不好', 57), ('认识', 56), ('而', 56), ('本来', 56), ('当', 56), ('过', 56), ('实力', 55), ('到了', 55), ('里面', 55), ('特别', 55), ('澜', 55), ('心态', 54), ('只能', 54), ('小王', 54), ('个人', 54), ('那种', 54), ('甄姬', 54), ('高', 54), ('游戏_日常', 54), ('加', 54), ('笑_哭', 54), ('着', 53), ('不管', 53), ('骂我', 53), ('最近', 53), ('这是', 53), ('电竞', 53), ('新_皮肤', 53), ('甚至', 52), ('辱骂', 52), ('只有', 52), ('哈哈哈', 52), ('就会', 52), ('像', ...

# %%
with open('M_FREQ.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['term', 'freq', 'label'])
    for item in sorted_term_freq:
        term, freq = item[0], item[1]
        if freq >= 10 and len(term) > 1:  # check frequency and term length
            writer.writerow([term, freq, ''])  # add blank label column

# %% [raw]
# # 2. Word2Vec

# %%
import pandas as pd
import jieba
import gensim
from gensim.utils import simple_preprocess
from gensim.models import Word2Vec
from gensim.models.phrases import Phrases, Phraser
import warnings

warnings.filterwarnings("ignore", category=DeprecationWarning)

jieba.load_userdict("dict.txt")

# Load the csv file
df = pd.read_csv('/Users/Lynn/Downloads/red/PP_merged.csv')

def sent_to_words_lower(sentences):
    for sent in sentences:
        sent = sent.lower()
        sent = re.sub(r'http\S+|https\S+', '', sent)  # remove http and https
        sent = re.sub('<[^>]+>', '', sent)  # remove HTML tags
        sent = re.sub('\S*@\S*\s?', '', sent)  # remove emails
        sent = re.sub('\s+', ' ', sent)  # remove newline chars
        sent = re.sub('[^\w\s]', ' ', sent)  # remove punctuations
        sent = re.sub('@\w+', '', sent)
        yield sent
        
# Define a function to remove stopwords and perform word segmentation using Jieba
def preprocess(sentence):
    stopwords = [line.strip() for line in open('stopwords.txt', 'r', encoding='utf-8').readlines()]
    sentence_depart = jieba.cut(sentence.strip())
    outstr = ''
    for word in sentence_depart:
        if word not in stopwords and len(word.strip()) > 0:
            outstr += word + ' '
    return outstr.strip()

# Preprocess the messages in the dataframe
df['tokenz'] = df['tokenz'].astype(str)
df['content1'] = list(map(preprocess, sent_to_words_lower(df['tokenz'].tolist())))

# Tokenize the preprocessed messages and build bigram and trigram models
result_fenci = [sent.split(' ') for sent in df['content1'].tolist()]
bigram = Phrases(result_fenci, min_count=10, threshold=10)
trigram = Phrases(bigram[result_fenci], min_count=10, threshold=10)
bigram_mod = Phraser(bigram)
trigram_mod = Phraser(trigram)
ngram_fenci = [trigram_mod[bigram_mod[doc]] for doc in result_fenci]

# Train a Word2Vec model on the tokenized messages
model = Word2Vec(ngram_fenci, vector_size=100, window=5, min_count=5, workers=4)

# %%
# Set the keyword and get the most similar words
keyword = '瑶妹'
similar_words = model.wv.most_similar(keyword, topn=1000)

# Iterate through the list of similar words, print their similarity score and frequency, and save them to a csv file
output = []
for word, score in similar_words:
    frequency = model.wv.get_vecattr(word, "count")
    similarity = model.wv.similarity(keyword, word)
    output.append([word, frequency, similarity])
    print(f"{word}: {similarity}, frequency: {frequency}")
# Out:
# 荣耀: 0.9994925260543823, frequency: 118
# 不能: 0.9994712471961975, frequency: 124
# 女_玩家: 0.9994580149650574, frequency: 438
# 皮肤: 0.9994460940361023, frequency: 490
# 不会: 0.9994437098503113, frequency: 120
# 这是: 0.9994397163391113, frequency: 60
# 都是: 0.9994369745254517, frequency: 233
# 峡谷: 0.9994359016418457, frequency: 136
# 段位: 0.9994359016418457, frequency: 91
# 玩家: 0.9994328022003174, frequency: 489
# 实力: 0.9994248747825623, frequency: 62
# 需要: 0.9994230270385742, frequency: 52
# 不想: 0.9994224309921265, frequency: 71
# 传说: 0.9994185566902161, frequency: 43
# 朋友: 0.9994171261787415, frequency: 163
# 女孩子: 0.9994118809700012, frequency: 230
# 一下: 0.9994110465049744, frequency: 154
# 英雄: 0.9994086623191833, frequency: 602
# 都有: 0.9994077086448669, frequency: 46
# 单排: 0.999400794506073, frequency: 73
# 主页: 0.9993976950645447, frequency: 67
# 的是: 0.9993942379951477, frequency: 75
# 有点: 0.9993941187858582, frequency: 94
# 不知道: 0.9993923306465149, frequency: 115
# 妹妹: 0.9993922114372253, frequency: 48
# 双排: 0.9993860125541687, frequency: 87
# 害羞: 0.9993821978569031, frequency: 54
# 选择: 0.9993807077407837, frequency: 62
# 工作: 0.9993804097175598, frequency: 30
# 国服: 0.9993790984153748, frequency: 101
# 打完: 0.9993779063224792, frequency: 58
# 可能: 0.9993776679039001, frequency: 97
# 知道: 0.9993759989738464, frequency: 103
# 让我: 0.9993748068809509, frequency: 96
# 都在: 0.999374508857727, frequency: 38
# 发现: 0.9993746280670166, frequency: 76
# 女生: 0.9993675351142883, frequency: 452
# 破防: 0.9993674159049988, frequency: 46
# 排位: 0.9993651509284973, frequency: 164
# 野王: 0.9993649125099182, frequency: 134
# 输了: 0.9993646144866943, frequency: 53
# 反应: 0.9988025426864624, frequency: 24
# 喝_奶茶: 0.9988019466400146, frequency: 35
# 高地: 0.9988020062446594, frequency: 18
# 王者_成长_计划_新春: 0.9988014101982117, frequency: 25
# 固玩: 0.9988011717796326, frequency: 46
# 小国: 0.9988009929656982, frequency: 17
# 身高: 0.9988005757331848, frequency: 19
# 成长_计划: 0.9988002181053162, frequency: 26
# 啊啊啊_啊啊啊: 0.9987996816635132, frequency: 20
# 退游: 0.9987992644309998, frequency: 19
# 阿离: 0.9987974762916565, frequency: 22
# 昨天: 0.9987973570823669, frequency: 22
# 多的: 0.9987948536872864, frequency: 18
# 瑶瑶_公主: 0.9987945556640625, frequency: 28
# 必须: 0.9987940788269043, frequency: 20
# 方式: 0.9987913966178894, frequency: 21
# 我想: 0.9987841248512268, frequency: 26
# 召集: 0.9987836480140686, frequency: 23
# 注意: 0.9987833499908447, frequency: 17
# 抓狂: 0.998781144618988, frequency: 18
# 倒是: 0.9987795948982239, frequency: 14
# 感受: 0.9987788796424866, frequency: 15
# 评论: 0.9987775683403015, frequency: 23
# 亚瑟: 0.9987769722938538, frequency: 21
# 变得: 0.9987685084342957, frequency: 15
# 一开始: 0.9987683892250061, frequency: 22
# 头像: 0.9987664222717285, frequency: 16
# 值得: 0.9987663626670837, frequency: 19
# 私信_梯队_种草: 0.9987643957138062, frequency: 18
# 这类: 0.9987617135047913, frequency: 18
# 不需要: 0.998756468296051, frequency: 22
# 邀请: 0.9987550973892212, frequency: 20
# 真实: 0.9987546801567078, frequency: 30
# 婉儿: 0.9987542033195496, frequency: 18
# 连胜: 0.9987539052963257, frequency: 24
# 快速: 0.9987530708312988, frequency: 24
# 点开: 0.9987505674362183, frequency: 17
# 发育_路: 0.998745858669281, frequency: 29
# 武则天: 0.9987444281578064, frequency: 21
# 男友: 0.9987441301345825, frequency: 19
# 弟弟: 0.9987438917160034, frequency: 40
# 核心: 0.9987435340881348, frequency: 16
# 消息: 0.9987409114837646, frequency: 19
# 回忆: 0.9987397193908691, frequency: 21
# 房间: 0.9987384080886841, frequency: 14
# 位移: 0.9987380504608154, frequency: 21
# 还会: 0.9987321496009827, frequency: 20
# 黑薯_问号: 0.9987318515777588, frequency: 22
# 类似: 0.9987303614616394, frequency: 17
# 时刻: 0.9987285137176514, frequency: 27
# 性别歧视: 0.9987283945083618, frequency: 30
# 帖子: 0.9987272024154663, frequency: 18
# 差点: 0.9987236857414246, frequency: 15
# 说是: 0.9987220764160156, frequency: 19
# 整个: 0.9987216591835022, frequency: 21
# 分段: 0.9987210631370544, frequency: 17
# 小明: 0.9987201690673828, frequency: 31
# 轻松: 0.9987201690673828, frequency: 23
# 曾经: 0.9987197518348694, frequency: 17
# 具有: 0.9987168908119202, frequency: 14
# 成功: 0.9987131357192993, frequency: 24
# 距离: 0.9987126588821411, frequency: 16
# 工具: 0.9987112283706665, frequency: 17
# 恋爱: 0.998710572719574, frequency: 30
# 我俩: 0.9987044930458069, frequency: 22
# 看了: 0.9987025856971741, frequency: 18
# 难度: 0.9986976981163025, frequency: 19
# 男大: 0.9986969828605652, frequency: 26
# 我方: 0.9984058141708374, frequency: 19
# 电话: 0.9983989596366882, frequency: 13
# 渣_男: 0.9983948469161987, frequency: 20
# 天天: 0.9983938336372375, frequency: 16
# 卸载: 0.9983935356140137, frequency: 17
# 做的: 0.9983895421028137, frequency: 14
# 左右: 0.9983882904052734, frequency: 16
# 叹气: 0.9983820915222168, frequency: 18
# 玩过: 0.9983818531036377, frequency: 17
# 二楼: 0.9983780384063721, frequency: 18
# 加油: 0.9983764886856079, frequency: 17
# 介绍: 0.9983764290809631, frequency: 17
# 表现: 0.9983726143836975, frequency: 16
# 手游: 0.9983710050582886, frequency: 24
# 瑶瑶: 0.9983661770820618, frequency: 20
# 效果: 0.9983641505241394, frequency: 11
# 下去: 0.9983639121055603, frequency: 16
# 两次: 0.9983630776405334, frequency: 17
# 进入: 0.9983625411987305, frequency: 14
# 吃瓜: 0.9983618259429932, frequency: 16
# 教程: 0.9983600974082947, frequency: 15
# 消费者: 0.9983599781990051, frequency: 7
# 四楼: 0.9983595013618469, frequency: 26
# 打得: 0.9983534216880798, frequency: 21
# 男女: 0.9983522891998291, frequency: 20
# 吧唧: 0.9983492493629456, frequency: 16
# 就行: 0.9983490705490112, frequency: 15
# 品牌: 0.9983476400375366, frequency: 10
# 前面: 0.9983449578285217, frequency: 13
# 无所谓: 0.998339831829071, frequency: 15
# 强化: 0.998339056968689, frequency: 11
# 电玩: 0.998337984085083, frequency: 27
# 考虑: 0.9983376860618591, frequency: 11
# 墨子: 0.9983359575271606, frequency: 15
# 小妲己: 0.9983309507369995, frequency: 15
# 简直: 0.9983290433883667, frequency: 13
# 更好: 0.9983232617378235, frequency: 16
# 在玩: 0.9983202219009399, frequency: 14
# 其他人: 0.9983200430870056, frequency: 9
# 乱杀: 0.9983198642730713, frequency: 18
# 入门: 0.9983183741569519, frequency: 15
# 完了: 0.9983126521110535, frequency: 15
# 百星: 0.9983109831809998, frequency: 12
# 慢慢: 0.9983109831809998, frequency: 18
# 也能: 0.9983080625534058, frequency: 15
# 下路: 0.9983052611351013, frequency: 17
# 衣服: 0.9983018040657043, frequency: 13
# 战队_收人: 0.998297393321991, frequency: 19
# 害羞_害羞: 0.9982958436012268, frequency: 17
# 氛围: 0.9982929825782776, frequency: 14
# 看起来: 0.9982926249504089, frequency: 11
# 打架: 0.998289942741394, frequency: 11
# 就好: 0.998286783695221, frequency: 13
# 区别: 0.9982866644859314, frequency: 18
# 开团: 0.998282253742218, frequency: 18
# 被动: 0.9982777833938599, frequency: 19
# 设置: 0.9982767701148987, frequency: 18
# 就想: 0.9982749223709106, frequency: 13
# 爆发: 0.9982737898826599, frequency: 18
# 夏洛特: 0.9982737302780151, frequency: 14
# 很好看: 0.9982736706733704, frequency: 13
# 男_大学生: 0.9982735514640808, frequency: 19
# 被我: 0.9982734322547913, frequency: 13
# 定位: 0.998270571231842, frequency: 11
# 挑战: 0.99826979637146, frequency: 16
# 解释: 0.9982653260231018, frequency: 11
# 来个: 0.998263955116272, frequency: 14
# 照片: 0.998263955116272, frequency: 16
# 回复: 0.9982606768608093, frequency: 11
# 黄金_薯: 0.998255729675293, frequency: 19
# 做到: 0.9982532858848572, frequency: 12
# 花钱: 0.9982518553733826, frequency: 17
# 推塔: 0.9982481002807617, frequency: 19
# 一套: 0.9982477426528931, frequency: 19
# 长得: 0.9982432126998901, frequency: 17
# 辱_女: 0.9982413649559021, frequency: 24
# 全能: 0.9982367753982544, frequency: 20
# 欺负: 0.9982268214225769, frequency: 17
# 栏目: 0.9982254505157471, frequency: 12
# 玩意: 0.9982222318649292, frequency: 12
# 从来不: 0.9982185363769531, frequency: 15
# 难听: 0.9982129335403442, frequency: 12
# 回家: 0.9982114434242249, frequency: 15
# 计划: 0.9982081055641174, frequency: 15
# 草丛: 0.9981994032859802, frequency: 17
# 分路: 0.9981938600540161, frequency: 16
# 开黑: 0.9981930255889893, frequency: 20
# 去了: 0.9981823563575745, frequency: 15
# 释放: 0.9981820583343506, frequency: 14
# 滴滴: 0.9981803894042969, frequency: 20
# 最强: 0.9981776475906372, frequency: 17
# 让人: 0.9981766939163208, frequency: 15
# 评论_区: 0.998173177242279, frequency: 19
# 具备: 0.9981674551963806, frequency: 9
# 压力: 0.9981613755226135, frequency: 16
# 增加: 0.9981533885002136, frequency: 14
# 赫兹: 0.9981504678726196, frequency: 14
# 不好意思: 0.9981498718261719, frequency: 15
# 至少: 0.9981411099433899, frequency: 16
# 差不多: 0.9981405735015869, frequency: 20
# 过了: 0.9981396794319153, frequency: 14
# 起码: 0.9981396198272705, frequency: 12
# 骂他: 0.9981386065483093, frequency: 11
# 垃圾: 0.9981352686882019, frequency: 19
# 下载: 0.9981353282928467, frequency: 11
# 更喜欢: 0.99813312292099, frequency: 9
# 昭君: 0.9981297850608826, frequency: 13
# 今年: 0.998127818107605, frequency: 13
# 关羽: 0.9981139302253723, frequency: 17
# 不在: 0.9981132745742798, frequency: 15
# 未来: 0.9981082677841187, frequency: 13
# 感情: 0.9981022477149963, frequency: 11
# 声音_好听: 0.9981010556221008, frequency: 15
# 两把: 0.9980974197387695, frequency: 13
# 开骂: 0.9980953931808472, frequency: 13
# 干扰: 0.9980936646461487, frequency: 10
# 比较多: 0.9980910420417786, frequency: 16
# 总是: 0.9980908632278442, frequency: 16
# 颜值: 0.9980871677398682, frequency: 23
# 典藏: 0.9980836510658264, frequency: 17
# 上面: 0.9980812668800354, frequency: 11
# 女装: 0.9980811476707458, frequency: 11
# 手机: 0.9980809688568115, frequency: 10
# 很强: 0.9980805516242981, frequency: 16
# 下班: 0.9980793595314026, frequency: 13
# 速度: 0.9980785250663757, frequency: 10
# 为什么要: 0.9980764985084534, frequency: 21
# 可以说: 0.998073935508728, frequency: 11
# 真正: 0.9980687499046326, frequency: 12
# 视角: 0.9980682730674744, frequency: 16
# 讨论: 0.9980652928352356, frequency: 13
# 这么多: 0.9980641603469849, frequency: 17
# 保证: 0.9980611801147461, frequency: 12
# 对线: 0.9980552196502686, frequency: 15
# 吐舌头: 0.9980531334877014, frequency: 11
# 下次: 0.998052716255188, frequency: 13
# 男孩: 0.998050332069397, frequency: 16
# 立刻: 0.9980442523956299, frequency: 10
# 不开: 0.9980412125587463, frequency: 14
# 高分: 0.9980379939079285, frequency: 12
# 新_英雄: 0.9980360269546509, frequency: 16
# 嘴巴: 0.9980342984199524, frequency: 12
# 难看: 0.998033344745636, frequency: 10
# 受不了: 0.9980312585830688, frequency: 13
# 大哥: 0.9980301260948181, frequency: 14
# 天幕: 0.9980295896530151, frequency: 10
# 歧视_女_玩家: 0.998026967048645, frequency: 22
# 峡谷_日常: 0.9980244040489197, frequency: 28
# 每一个: 0.9980192184448242, frequency: 16
# 有了: 0.9980190396308899, frequency: 14
# 又是: 0.9980151653289795, frequency: 12
# 精彩: 0.9980148077011108, frequency: 16
# 越塔: 0.9980079531669617, frequency: 10
# 账号: 0.9980071783065796, frequency: 16
# 翻盘: 0.9980011582374573, frequency: 16
# 多次: 0.99800044298172, frequency: 11
# 诸葛亮: 0.9979993104934692, frequency: 15
# 来看: 0.9979962706565857, frequency: 14
# 回归: 0.9979960918426514, frequency: 13
# 路线: 0.9979928135871887, frequency: 11
# 选个: 0.9979854226112366, frequency: 16
# 廉颇: 0.9979835152626038, frequency: 13
# 金标: 0.9979791641235352, frequency: 14
# 搞笑_视频: 0.9979774355888367, frequency: 18
# 抢了: 0.9979740977287292, frequency: 14
# 第一个: 0.9979704022407532, frequency: 21
# 黄金: 0.9979691505432129, frequency: 13
# 听到: 0.9979681372642517, frequency: 12
# 形象: 0.9979552030563354, frequency: 12
# 晦气: 0.9979493618011475, frequency: 17
# 好吗: 0.997947633266449, frequency: 14
# 一点点: 0.9979469180107117, frequency: 11
# 举报_不成功: 0.9979428052902222, frequency: 19
# 是因为: 0.9979410767555237, frequency: 20
# 上班: 0.9979408383369446, frequency: 11
# 阶段: 0.997940719127655, frequency: 13
# 两局: 0.9979406595230103, frequency: 13
# 都要: 0.9979404807090759, frequency: 13
# 朋友圈: 0.9979296922683716, frequency: 11
# 不太: 0.9979291558265686, frequency: 18
# 冷知识: 0.9979265332221985, frequency: 11
# 脑子: 0.9979261159896851, frequency: 11
# 地图: 0.997925877571106, frequency: 13
# 刚刚: 0.9979168772697449, frequency: 11
# 优化: 0.9979131817817688, frequency: 16
# 无情: 0.9979123473167419, frequency: 9
# 免费: 0.9979108572006226, frequency: 19
# 习惯: 0.9979029297828674, frequency: 15
# 加了_好友: 0.997897744178772, frequency: 12
# 特殊: 0.9978948831558228, frequency: 10
# 不止: 0.9978924989700317, frequency: 11
# 王子: 0.9978919625282288, frequency: 9
# 阴阳怪气: 0.9978863596916199, frequency: 11
# 整局: 0.9978847503662109, frequency: 12
# 开大: 0.9978846311569214, frequency: 13
# 队友_贴_贴: 0.9978834390640259, frequency: 12
# 闪现: 0.9978817105293274, frequency: 14
# 不可能: 0.997881293296814, frequency: 10
# 女装品牌: 0.9978809356689453, frequency: 6
# 客服: 0.9978808760643005, frequency: 10
# 鼓励: 0.9978760480880737, frequency: 12
# 他俩: 0.9978731274604797, frequency: 10
# 以下: 0.9978728294372559, frequency: 15
# 玩玩: 0.9978727102279663, frequency: 11
# 加上: 0.9978723526000977, frequency: 14
# 无聊: 0.9978718161582947, frequency: 18
# 没怎么: 0.9978679418563843, frequency: 10
# 赶紧: 0.9978675842285156, frequency: 15
# 带着: 0.9978626370429993, frequency: 14
# 交流: 0.9978607892990112, frequency: 13
# 精神: 0.9978596568107605, frequency: 9
# 发出: 0.9978557825088501, frequency: 13
# 新春: 0.9978553056716919, frequency: 11
# 调整: 0.9978516101837158, frequency: 9
# 自由: 0.9978511929512024, frequency: 10
# 蒙_犽: 0.9978510141372681, frequency: 13
# 的啊: 0.9978464245796204, frequency: 16
# 看完: 0.9978430271148682, frequency: 13
# 全局: 0.9978394508361816, frequency: 11
# 净化: 0.9978368282318115, frequency: 12
# 色色: 0.9978365302085876, frequency: 12
# 后悔: 0.9978359937667847, frequency: 10
# 害怕: 0.9978358149528503, frequency: 14
# 依旧: 0.9978353381156921, frequency: 11
# 很帅: 0.997830867767334, frequency: 15
# 再见_再见: 0.9978303909301758, frequency: 14
# 出场率: 0.9978299736976624, frequency: 11
# 使用: 0.9978248476982117, frequency: 14
# 之间: 0.9978216290473938, frequency: 14
# 默默: 0.9978206157684326, frequency: 13
# 点了: 0.9978164434432983, frequency: 12
# 足够: 0.9978147149085999, frequency: 10
# 封神: 0.997810959815979, frequency: 10
# 傻子: 0.9978086948394775, frequency: 15
# 往往: 0.9977973699569702, frequency: 11
# 白起: 0.9977965354919434, frequency: 11
# 一段时间: 0.9977959990501404, frequency: 12
# 老师: 0.9977911710739136, frequency: 9
# 钓鱼: 0.9977900981903076, frequency: 12
# 刻板印象: 0.9977890849113464, frequency: 14
# 老公: 0.9977890253067017, frequency: 18
# 心里: 0.9977885484695435, frequency: 13
# 周瑜: 0.9977877140045166, frequency: 9
# 抢_位置: 0.9977854490280151, frequency: 14
# 三排: 0.9977750182151794, frequency: 16
# 试试: 0.9977717995643616, frequency: 16
# 打字: 0.9977699518203735, frequency: 12
# 惩戒: 0.9977656602859497, frequency: 12
# 制裁: 0.9977647662162781, frequency: 14
# 就有: 0.9977646470069885, frequency: 10
# 合十: 0.9977635741233826, frequency: 8
# 三丽鸥: 0.9977635741233826, frequency: 16
# 内容: 0.9977619051933289, frequency: 11
# 有问必答: 0.9977607131004333, frequency: 12
# 大学生: 0.9977605938911438, frequency: 12
# 老_玩家: 0.9977546334266663, frequency: 12
# 高手: 0.997753381729126, frequency: 18
# 小满: 0.9977532625198364, frequency: 11
# 三楼: 0.9977505803108215, frequency: 16
# 沈梦溪: 0.9977494478225708, frequency: 9
# 沉默: 0.9977452754974365, frequency: 13
# 练习: 0.9977419376373291, frequency: 10
# 加了: 0.9977417588233948, frequency: 11
# 很喜欢: 0.997740626335144, frequency: 16
# 建模: 0.9977360367774963, frequency: 9
# 青春: 0.9977350831031799, frequency: 10
# 拿到: 0.997732937335968, frequency: 14
# 风气: 0.997730553150177, frequency: 13
# 笑_哭笑: 0.9977255463600159, frequency: 11
# 不限: 0.9977244138717651, frequency: 12
# 无畏: 0.9977209568023682, frequency: 9

# %%
output_df = pd.DataFrame(output, columns=['word', 'frequency', 'similarity'])
output_df.to_csv('F.csv', index=False)
